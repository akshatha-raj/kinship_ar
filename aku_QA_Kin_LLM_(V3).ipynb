# %% [markdown]
# <a href="https://colab.research.google.com/github/akshatha-raj/kinship_ar/blob/main/aku_QA_Kin_LLM_(V3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installation

# %%
# install
# !pip install llama-index

# %%
#🎄 Get base class and data

# %%
# check it
# !ls -la
# Out:
# total 720
# drwxrwxr-x  3 ec2-user ec2-user   4096 Nov 29 06:58 .
# drwxrwxr-x 10 ec2-user ec2-user   4096 Nov 27 09:15 ..
# -rw-rw-r--  1 ec2-user ec2-user 152867 Nov 28 09:25 aku_fastapi.ipynb
# -rw-rw-r--  1 ec2-user ec2-user   1543 Nov 27 14:49 app_p2.py
# -rw-rw-r--  1 ec2-user ec2-user  40875 Nov 28 09:20 app.py
# -rw-rw-r--  1 ec2-user ec2-user    134 Nov 28 16:47 email_s1.csv
# -rw-rw-r--  1 ec2-user ec2-user    293 Nov 28 16:47 fail_functions.csv
# drwxrwxr-x  2 ec2-user ec2-user   4096 Nov 28 10:06 .ipynb_checkpoints
# -rw-rw-r--  1 ec2-user ec2-user   3887 Nov 28 16:47 Parent_intro.csv
# -rw-rw-r--  1 ec2-user ec2-user 463188 Nov 29 06:58 QA_Kin LLM (V3).ipynb
# -rw-rw-r--  1 ec2-user ec2-user     74 Nov 16 16:06 README.md
# -rw-rw-r--  1 ec2-user ec2-user  16576 Nov 23 17:31 testing.csv
# -rw-rw-r--  1 ec2-user ec2-user  18784 Nov 22 10:36 Vet_Chat_conv.csv

# %%
# check it
# !pwd
# Out:
# /home/ec2-user/SageMaker/kin-ai-1/sandbox/akshatha-corner

# %%
# be sure you are on "develop" branch OR your branch
# !git branch
# Out:
# * develop
#   master

# %%
# switch to your branch (or I use develop branch because I play in my corner ... mostly :-)
# !git checkout develop
# Out:
# M	sandbox/duc-corner/Stage_AWS_QA_kin_llm_fine_tune_v3.ipynb
# M	sandbox/duc-corner/app.py
# M	sandbox/duc-corner/fastapi.ipynb
# M	sandbox/duc-corner/kin_llm_fine_tune_v4.ipynb
# M	sandbox/duc-corner/requirements.txt
# M	sandbox/old-google-colab/Rahul_clean_and_visualise_article_data.ipynb
# M	sandbox/old-google-colab/Srijita_clean_and_visualise_article_data.ipynb
# M	sandbox/old-google-colab/kin_aws_data.ipynb
# M	sandbox/old-google-colab/kin_llm_fine_tune_v2.ipynb
# M	sandbox/srijita-corner/Stage_AWS_Srijita_QA_kin_llm_fine_tune_v3.ipynb
# Already on 'develop'
# Your branch is up to date with 'origin/develop'.

# %%
# check out where pluto is at
# !ls -la ../../
# Out:
# total 68
# drwxrwxr-x 12 ec2-user ec2-user 4096 Nov 28 22:28 .
# drwxr-xr-x  7 ec2-user ec2-user 4096 Nov 16 14:40 ..
# -rw-rw-r--  1 ec2-user ec2-user  419 Nov 16 16:06 Dockerfile
# -rw-rw-r--  1 ec2-user ec2-user   31 Nov  9 16:46 duchaba_test.txt
# drwxrwxr-x  8 ec2-user ec2-user 4096 Nov 29 06:58 .git
# drwxrwxr-x  3 ec2-user ec2-user 4096 Nov  9 16:46 .github
# -rw-rw-r--  1 ec2-user ec2-user   14 Nov 28 22:05 .gitignore
# drwxrwxr-x  4 ec2-user ec2-user 4096 Nov 28 22:05 infrastructure
# drwxrwxr-x  2 ec2-user ec2-user 4096 Nov 21 04:48 .ipynb_checkpoints
# drwxrwxr-x  7 ec2-user ec2-user 4096 Nov 17 06:35 kin_ai_app
# drwxrwxr-x  3 ec2-user ec2-user 4096 Nov  9 16:46 kin_article_data
# drwxrwxr-x  3 ec2-user ec2-user 4096 Nov 23 17:31 kin-chat-and-email-data
# drwxrwxr-x  3 ec2-user ec2-user 4096 Nov 20 06:21 pluto
# drwxrwxr-x  4 ec2-user ec2-user 4096 Nov  9 16:46 POC
# -rw-rw-r--  1 ec2-user ec2-user 5879 Nov  9 16:46 README.md
# ...

# %%
#💗 Instatiate Pluto

# %%
# where am I?
# !pwd
# Out:
# /home/ec2-user/SageMaker/kin-ai-1/sandbox/akshatha-corner

# %%
# where is pluto
# !ls -la /home/ec2-user/SageMaker/kin-ai-1/pluto/
# Out:
# total 48
# drwxrwxr-x  3 ec2-user ec2-user  4096 Nov 20 06:21 .
# drwxrwxr-x 12 ec2-user ec2-user  4096 Nov 28 22:28 ..
# drwxrwxr-x  2 ec2-user ec2-user  4096 Nov 20 06:21 .ipynb_checkpoints
# -rw-rw-r--  1 ec2-user ec2-user 25603 Nov  9 16:46 pluto.py
# -rw-rw-r--  1 ec2-user ec2-user    53 Nov  9 16:46 pluto_requirements.txt
# -rw-rw-r--  1 ec2-user ec2-user   605 Nov  9 16:46 README.md

# %%
# git pull
# !git pull
# Out:
# Already up to date.

# %%
# install required lib
fname_req = '/home/ec2-user/SageMaker/kin-ai-1/pluto/pluto_requirements.txt'
# !pip install -r {fname_req}

# %%
# prompt: use jupyter notebook magic command to run luto/pluto.py

fname = "/home/ec2-user/SageMaker/kin-ai-1/pluto/pluto.py"
# %run {fname}

# %%
# %%write app.py

# choose any object name here. I choose "monty" after my dog.
monty = Pluto_Happy("Monty the seeker of truth.")
# Out:
# ---------------------------------- : ----------------------------------
#                   Hello from class : <class '__main__.Pluto_Happy'> Class: Pluto_Happy
#                          Code name : Monty the seeker of truth.
#                          Author is : Duc Haba
# ---------------------------------- : ----------------------------------

# %%
# check out monty functions doc
help(monty)
# Out:
# Help on Pluto_Happy in module __main__ object:
#
# class Pluto_Happy(builtins.object)
#  |  Pluto_Happy(name='Pluto', *args, **kwargs)
#  |
#  |  The Pluto projects starts with fun AI hackings and become a part of my
#  |  first book "Data Augmentation with Python" with Packt Publishing.
#  |  Amazon book link is: https://www.amazon.com/dp/1803246456
#  |
#  |  In particular, Pluto_Happy is a clean and lite kernel of a simple class,
#  |  and using @add_module decoractor to add in specific methods to be a new class,
#  |  such as Pluto_HFace with a lot more function on HuggingFace, LLM and Transformers.
#  |
#  |  The original code was governed by the MIT License, https://spdx.org/licenses/MIT.html
#  |  unless directly specified by the author, Duc Haba, otherwise.
#  |
#  |  Args:
#  |      name (str): the display name, e.g. "Hanna the seeker"
#  |
#  |  Returns:
#  |      (object): the class instance.
#  |
#  |  Methods defined here:
#  |
# ...

# %%
# %%write -a app.py

fname_req = '/home/ec2-user/SageMaker/kin-ai-1/pluto/pluto_requirements.txt'
# check out monty server info.
monty.fname_requirements = fname_req
monty.print_info_self()
# Out:
# ---------------------------------- : ----------------------------------
#                        Hello, I am : Monty the seeker of truth.
#                     I will display : Python, Jupyter, and system info.
#              For complete doc type : help(pluto) ...or help(your_object_name)
#                                  . : .
#                                ... : ¯\_(ツ)_/¯
# ---------------------------------- : ----------------------------------
#                             System : Info
# Total memory: 59.84 GB
# Available memory: 43.51 GB
# Memory usage: 0.26%
# CPU type: Intel(R) Xeon(R) CPU E5-2686 v4 @ 2.30GHz, arch: X86_64
# Number of CPU cores: 8
# CPU usage: 0.9%
# Python version: 3.10.12.final.0 (64 bit)
# ---------------------------------- : ----------------------------------
#                                GPU : Info
# GPU type: Tesla V100-SXM2-16GB
# GPU ready staus: True
# Number of GPUs: 1
# Total Memory: 16.00 GB
# Free Memory: 14.66 GB
# ...

# %%
#

# just for fun see how fast is this server compare to Duc's Colab
monty.print_petaflops()
# Out:
#                              Model : TTM, Tiny Torch Model on: CPU
#                              Flops : 16,859,136 flops
#                  Total elapse time : 0.36971473693847656 seconds
#                     Flops compared : 0.93% of Google Colab Pro
#                             Info 0 : Tensors device: cpu
#                             Info 1 : flops: 16,859,136
#                             Info 2 : params: 336
#                             Info 3 : epoch: 1
#                             Info 4 : sec: 0.36971473693847656
#                             Info 5 : Flops/s: 45,600,389.477592
#                             Info 6 : PetaFlops/s: 4.5600389477591996e-08
#                             Info 7 : PetaFlops/day: 0.003939873650863949
#                             Info 8 : 1 PetaFlopsDay (on this system will take): 253.82 days
# ---------------------------------- : ----------------------------------
#                              Model : TTM, Tiny Torch Model on: GPU
# ...

# %%
#🐣 Install LLM and LlamaIndex

# %%
# !pip install openai

# %%
# %%write -a app.py

import openai
import llama_index
import llama_index.llms
import os

# %%
# # STOP: uncommend these and set your key
ax = monty.encrypt_it('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')
monty._gpt_crkey = ax

# %%
# # check it.
monty.decrypt_it(ax)
# Out:
# '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'

# %%
# %%write -a app.py

# STOP: user your key

# you don't have to use the encrypted key
openai.api_key = monty.decrypt_it(monty._gpt_crkey)

# YOUR KEY: you can use the naked key
openai.api_key = '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'
os.environ["OPENAI_API_KEY"] = openai.api_key

# %%
#Check on Openai key and Lllamindex install

# %%
# get the llm engine
llm_gpt = llama_index.llms.OpenAI(model="gpt-3.5-turbo", temperature=0.35, max_tokens=1000)

# %%
# test it out
mesg1 = [
  llama_index.llms.ChatMessage(role="system", content="Talk like a father talking to a 5 years old son."),
  llama_index.llms.ChatMessage(role="user", content="Tell me a joke."),
]
resp = llm_gpt.chat(mesg1)
print(resp.message)
# Out:
# assistant: Sure, buddy! Why don't dinosaurs ever talk? Because they're all dead and can't say a word!

# %%
#🐠 Import index

# %%
# once again, know where you are
# !pwd
# Out:
# /home/ec2-user/SageMaker/kin-ai-1/sandbox/akshatha-corner

# %%
# %%write -a app.py

fname = '/home/ec2-user/SageMaker/kin-ai-1/kin_ai_app/deploy_sprint2_articles/index_kin_all640_article'
monty.index_all_articles = llama_index.load_index_from_storage(llama_index.StorageContext.from_defaults(persist_dir=fname))

# %%
# check it
type(monty.index_all_articles)
# Out:
# llama_index.indices.vector_store.base.VectorStoreIndex

# %%
#Query Engine

# %%
# %%write -a app.py

# create an llm gpt engine for monty
monty.llm_gpt4 = llama_index.llms.OpenAI(model="gpt-4", temperature=0.1, max_tokens=1600)
monty.service_context4 = llama_index.ServiceContext.from_defaults(llm=monty.llm_gpt4)
# create the query engine using the gpt 3.5 turbo
monty.geng_gpt4 = monty.index_all_articles.as_query_engine(ServiceContext=monty.service_context4)

# %%
# !pwd
# Out:
# /home/ec2-user/SageMaker/kin-ai-1/sandbox/akshatha-corner

# %%
# searching the right path of .csv file
# !ls /home/ec2-user/SageMaker/kin-ai-1
# Out:
# Dockerfile	  infrastructure  kin_article_data	   pluto  README.md
# duchaba_test.txt  kin_ai_app	  kin-chat-and-email-data  POC	  sandbox

# %%
# take the first 30 files
fname = '/home/ec2-user/SageMaker/kin-ai-1/kin-chat-and-email-data/clean_chat_and_email_historic_data.csv'
# !head -30 {fname} > email_s1.csv

# %%
# # check it out
df_historic_data = pandas.read_csv('email_s1.csv')
df_historic_data.head()
# Out:
#           version https://git-lfs.github.com/spec/v1
# 0  oid sha256:e4a7ace501532414c9522232a5fad0ac441...
# 1                                     size 421611349

# %% [markdown]
# # Ask Vet Anything

# %%
import textwrap
# happy path
question = "Monty, my beloved dog, is sad. What can I do?"
response = monty.geng_gpt4.query(question)
print(textwrap.fill(str(response), width=120))
# Out:
# If your beloved dog Monty is feeling sad, there are a few things you can do to help him. First, it's important to keep
# track of his mood and behavior to understand his emotions better. Dogs may not display their grief in the same way
# humans do, so it's essential to be observant. Give Monty some time to adjust to any changes and be proactive in
# providing support. If his new behavior seems to require training or if he becomes anxious or aggressive, consider
# reaching out to a professional who can help develop a plan for him. Remember, adjusting to a new normal takes time, and
# it's crucial to respect Monty's unique way of processing emotions.

# %%
import textwrap
# happy path
question = "Monty, my beloved cat, is sad. What can I do?"
response = monty.geng_gpt4.query(question)
print(textwrap.fill(str(response), width=120))
# Out:
# Talk to your vet about whether switching up Monty's diet or offering some mood-boosting, stress-relieving supplements
# might help. Additionally, spending extra time with Monty, even if you're both curled up under a blanket and watching
# television, can be a necessary mood booster for both of you.

# %%
#QA Testing - Chat session data

# %%
# %%writefile -a app.py

monty.session_1 = """
Title: A Concerned Husky Owner and Understanding Veterinarian

[Setting: A brightly lit veterinarian clinic. A woman, Jane, stands by the door with a huskie named Luna by her side. Dr. Samuel, the veterinarian, sits behind the desk. His medical certificate hangs on the wall, next to a small plaque indicating his condition: epilepsy.]

Jane: [holding Luna’s leash tightly] "Hello, Dr. Samuel. I've heard so much about you. I hope you can help Luna; she’s been acting a bit off lately."

Dr. Samuel: [smiling warmly] "Hello Jane, and hello to you too, Luna! I'll do my best. Can you describe what's been going on?"

Jane: "Well, over the past week, she’s been very lethargic and doesn’t seem to respond as quickly as she used to. At first, I thought it might be her age, but it seems too sudden."

Dr. Samuel: "Hmm. Any changes in her diet, environment, or daily routine?"

Jane: "No, not at all. Everything has been consistent."

Dr. Samuel: "I see. We'll certainly look into it. If at any moment you're uncomfortable, please let me know."

Jane: [looking surprised but appreciative] "Oh, thank you for sharing that with me. I think it's brave of you to work in this field with that condition. But Luna and I trust you."

Dr. Samuel: "Thank you, Jane. It's important for me to advocate for those with conditions like mine and show that we can lead successful lives. Now, back to Luna. Any recent incidents that might have caused stress?"

Jane: "Not that I can think of. But I did notice she had what looked like a short tremor a couple of days ago. It lasted only a few seconds, and then she seemed fine."

Dr. Samuel: [leaning forward with interest] "That's an important detail. Seizures can manifest in various ways in dogs, much like in humans. They can range from those tiny tremors you mentioned to more severe forms. It's possible Luna experienced a minor seizure."

Jane: "Oh my! That's concerning. Is it something like epilepsy?"

Dr. Samuel: "It could be. Epilepsy in dogs isn't uncommon, and huskies are among the breeds that can be predisposed to it. However, it’s essential not to jump to conclusions. We'll need to run some tests to determine the cause."

Jane: "Of course. I just want what's best for Luna."

Dr. Samuel: "I understand. And I'm here to help. Let's start with a complete check-up and blood tests. Depending on the results, we might need to look into further neurological evaluations."

Jane: "Thank you, Dr. Samuel. I'm glad we're in capable hands."

Dr. Samuel: "It's my pleasure, Jane. And remember, even if it turns out to be epilepsy, many dogs live full, happy lives with the right treatment and care. Just like humans."

Jane: [smiling] "Thank you. That’s comforting to hear."

[End Scene.]
"""
monty.session_1_half = """
My dog Monty is sad, and he won't eat. What can I do to help?
"""
monty.session_2 = """
[Setting: A cozy veterinarian clinic, filled with the soft hum of fluorescent lights overhead. In the center of the room, Mrs. Collins holds a fluffy Persian cat named Muffin in her arms. Dr. Martinez, the veterinarian, is seated behind a desk, looking over Muffin's previous records.]

Mrs. Collins: [stroking Muffin's fur gently] "Dr. Martinez, I'm so worried. Muffin has always been such a good eater, but she's barely touched her food for days."

Dr. Martinez: [looking up with a reassuring smile] "Hello Mrs. Collins. It's always a pleasure to see Muffin, even under these circumstances. Can you tell me when she last ate properly?"

Mrs. Collins: "It's been about four days. At first, I thought she might be bored with her food, so I tried giving her a new brand, but she didn't seem interested in that either."

Dr. Martinez: "Have there been any other changes? Vomiting, diarrhea, lethargy, or behavioral shifts?"

Mrs. Collins: "She's been more withdrawn than usual. I found her hiding under the bed more often, which isn't like her at all."

Dr. Martinez: "I see. Persians, with their distinct facial structures, can sometimes develop dental or oral issues that might deter them from eating. But behavioral changes can also indicate discomfort or illness elsewhere. I'd like to conduct a full examination to rule out any potential problems. With your permission, of course."

Mrs. Collins: "Of course, Dr. Martinez. I just want to know what's wrong and how I can help her."

Dr. Martinez: [gently lifting Muffin from Mrs. Collins's arms and placing her on the examination table] "Let's start by checking her teeth and mouth."

[After a few moments of examining Muffin's mouth]

Dr. Martinez: "Her teeth seem to be in good shape, no apparent dental issues. Let's check her abdomen."

[Muffin gives a low growl as Dr. Martinez gently presses on her abdomen]

Dr. Martinez: "She seems a bit tender here. It's possible she could have an obstruction or some gastrointestinal discomfort. We might need to take an X-ray to be sure."

Mrs. Collins: [looking worried] "Oh dear! Is it serious?"

Dr. Martinez: "It's too early to say, Mrs. Collins. But it's good that you brought her in when you did. Early detection can make all the difference."

Mrs. Collins: "Please do whatever you need to do. I just want her to be okay."

Dr. Martinez: "We'll do our best. Let's get those X-rays and see if we can pinpoint the issue. And don't worry, Mrs. Collins, Muffin is in good hands."

Mrs. Collins: [sighing with relief] "Thank you, Dr. Martinez. I knew bringing her here was the right choice."

[End Scene.]
"""
monty.session_3 = """
Mr. Barkley: "Dr. Whiskerstein! Emergency! Rover thinks he's a cat!"

Dr. Whiskerstein: [peering through the giant magnifying glass at Rover, causing the dog's eyes to comically enlarge] "Hmm... indeed! Very cat-like symptoms! Does he also hate water and climb trees?"

Mr. Barkley: "No, but he's NOT eating his food! Instead, he's been batting at this feathered cat toy for hours. Yesterday, he tried to fit into a cardboard box! It was... a spectacle."

Dr. Whiskerstein: "Oh my! Did he also try to conquer the world with his cuteness and indifference?"

Mr. Barkley: "Well, he did knock a vase off the table and then looked at me like it was my fault."

Dr. Whiskerstein: [gasping dramatically] "The transformation is complete! Tell me, has he been hanging around any feline influencers lately?"

Mr. Barkley: "Well, my neighbor did get a new cat, Sir Purr-a-Lot, who's always wearing those trendy cat sunglasses. They've been peering at each other across the fence."

Dr. Whiskerstein: "Ah-ha! Sir Purr-a-Lot strikes again! He's been teaching dogs the way of the cat. Last week, a bulldog came in here trying to use a litter box!"

Mr. Barkley: "Goodness! What do we do, Doc? I miss my dog who, you know, acted like a dog."

Dr. Whiskerstein: "Fear not! I prescribe... a week of doggy activities! Fetch, tug of war, and absolutely NO cat videos on YouTube."

Mr. Barkley: "And what about his diet?"

Dr. Whiskerstein: "Swap the feathered toys with bacon treats. If that doesn't bring the dog out in him, I don’t know what will!"

Mr. Barkley: "Thank you, Dr. Whiskerstein! Come on, Rover. Let’s reclaim your canine pride."

Dr. Whiskerstein: [saluting with the oversized magnifying glass] "Godspeed, Mr. Barkley! And beware of those feline influencers."

[End Scene.]
"""
monty.duc_profile = """
Duc is a hansome man in his mid 40. He is active and love to garden.
His dog Monty is a siberian husky that love to chase squirrel, to climb tree, to swim in river, and he is 3 years old.
"""

# %%
#testing using .csv file
import textwrap
import pandas as pd
df = pd.read_csv('testing.csv')
conversation= df.loc[3, 'input']
response = monty.geng_gpt4.query(conversation)
print(textwrap.fill(str(response), width=120))
# Out:
# Yes, the veterinarian can help the cat owner with their cat's suspected urinary tract infection (UTI). The veterinarian
# suggests scheduling an appointment at the veterinary clinic for a thorough examination and urinalysis to confirm the
# diagnosis. In the meantime, the cat owner can ensure their cat has access to fresh water at all times to encourage
# urination and help flush out the urinary tract. They should also keep the litter box clean and easily accessible. The
# veterinarian advises against giving over-the-counter medications without veterinary guidance. Once the urinalysis
# results are available, the veterinarian can discuss any necessary dietary adjustments or supplements to support the
# cat's urinary tract health. The veterinarian reassures the cat owner that UTIs in cats are not typically contagious to
# humans but advises practicing good hygiene, such as washing hands thoroughly after handling the cat or cleaning the
# ...

# %% [markdown]
# # Four ask_vet... methods

# %%
# testing Happy path
import textwrap
response = monty.geng_gpt4.query("I have a dog, and its not feeling well, what should i do?")
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = monty.geng_gpt4.query("I have a cat, and its not feeling well, what should i do?")
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = monty.geng_gpt4.query("I have a cat, and it has Upper Respiratory Infections ")
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = monty.geng_gpt4.query("I have a , and it has Diabetes ")
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = monty.geng_gpt4.query("I have a cat, and it has Diabetes ")
print(textwrap.fill(str(response), width=120))
# Out:
# Contact your vet or local emergency clinic and describe your dog's symptoms. They should be able to advise you on
# whether you should sit tight or schedule an appointment. Trust your gut and seek professional advice to ensure your dog
# receives the necessary care.
# ----------------------------------------
# It is important to assess the situation and determine if your cat's condition requires immediate medical attention. If
# your cat is experiencing any of the following symptoms, it is recommended to take them to a veterinarian or an emergency
# veterinary hospital: obvious signs of pain, straining to urinate or defecate, difficulty breathing, significant bleeding
# or an open wound, seizures or collapsing episodes, inability to move one or more limbs, or ingestion of any toxin or
# poison. If your cat's symptoms are less severe or you are unsure, it is best to contact your regular veterinarian for
# guidance or consider using veterinary telemedicine for real-time advice.
# ...

# %%
# %%testing the normal conv with .csv file with different questions (without add method)

#@add_method(Pluto_Happy)
import textwrap
import pandas as pd
df = pd.read_csv('testing.csv')
conversation = df.loc[2, 'input']
#def ask_vet_during_chat(self, session):
q1 = 'Using the following veterinarian chat session as the input context, \n'
q2 = 'Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
question = f'{q1}{q2}\n--------------------\nThe veterinarian chat session:\n\n{conversation}'
resp = monty.geng_gpt4.query(question)

print(textwrap.fill(str(response), width=120))
# Out:
# It is important to manage your cat's diabetes with the right tools. Cats with diabetes need to be treated with a
# combination of insulin and diet. The right diet can help maintain the appropriate weight and benefit your cat's
# metabolism. It is recommended to discuss your options with your vet, as they may prescribe a therapeutic diet for your
# cat. While prescription diets and homemade meals are ideal, there are suitable over-the-counter options available as
# well. The food should be low in carbohydrates (less than 12 percent) and moderate-to-high in protein (greater than 40
# percent). It is also important to prevent your cat from becoming overweight or obese, as this can predispose them to
# developing diabetes.

# %%
# %%testing the normal conv with .csv file with different questions (with add method)

import textwrap
import pandas as pd
df = pd.read_csv('testing.csv')
conversation = df.loc[0, 'input']
@add_method(Pluto_Happy)
def ask_vet_after_chat(self, session):
    q1 ='Using the following veterinarian chat session as the input context, \n'
    q2 ='1. Write a short summary of the veterinarian chat session in a friendly natural conversation tone.\n'
    q3 ='2. Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}{q3}\n--------------------\nThe veterinarian chat session:\n\n{session}'
    resp = monty.geng_gpt4.query(question)
    return resp
response = ask_vet_during_chat(monty, conversation)
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = ask_vet_during_chat(monty, "My dog is not feeling well")
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = ask_vet_during_chat(monty, "My cat is not feeling well, What should I do?")
print(textwrap.fill(str(response), width=120))
# Out:
# 1. "UTIs Suck for Your Cat, Too" :: https://thewildest.com/cat-health/cat-uti 2. "Spot lumps, limps, and lethargy early
# on" :: [article URL not provided]
# ----------------------------------------
# 1. "Your Veterinarian's Top 8 Pet Peeves" :: https://thewildest.com/pet-health/veterinarians-pet-peeves 2. "10 Tips to
# Achieve VetVisit Bliss For Your Dog" :: https://thewildest.com/dog-health/tips-vet-visit-bliss
# ----------------------------------------
# 1. "How to Find the Right Vet For Your Cat" :: https://thewildest.com/cat-health/how-to-find-a-cat-vet 2. "Ways to lower
# your bill without compromising your pet's health" :: [Article URL not provided]

# %%
# %%testing the - Recomend two best article for each question (with add method and with only one question)

import textwrap
import pandas as pd
df = pd.read_csv('testing.csv')
conversation = df.loc[0, 'input']
@add_method(Pluto_Happy)
def ask_vet_after_chat(self, session):
    q1 ='Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}\n--------------------\nThe veterinarian chat session:\n\n{session}'
    resp = monty.geng_gpt4.query(question)
    return resp
response = ask_vet_during_chat(monty, conversation)
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = ask_vet_during_chat(monty, "My dog is not feeling well")
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = ask_vet_during_chat(monty, "My cat is not feeling well, What should I do?")
print(textwrap.fill(str(response), width=120))
# Out:
# 1. "UTIs Suck for Your Cat, Too" :: https://thewildest.com/cat-health/cat-uti 2. "Spot lumps, limps, and lethargy early
# on" :: [article URL not provided]
# ----------------------------------------
# 10 Tips to Achieve VetVisit Bliss For Your Dog :: https://thewildest.com/dog-health/tips-vet-visit-bliss Your
# Veterinarian's Top 8 Pet Peeves :: https://thewildest.com/pet-health/veterinarians-pet-peeves
# ----------------------------------------
# 1. "How to Find the Right Vet For Your Cat" :: https://thewildest.com/cat-health/how-to-find-a-cat-vet 2. "Ways to lower
# your bill without compromising your pet's health" :: [article URL not provided]

# %%
import textwrap
import pandas as pd
df = pd.read_csv('testing.csv')
conversation = df.loc[0, 'input']
@add_method(Pluto_Happy)
def ask_vet_during_chat(self, session):
    q1 ='Using the following veterinarian chat session as the input context, \n'
    q2 ='Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}\n--------------------\nThe veterinarian chat session:\n\n{session}'
    resp = monty.geng_gpt4.query(question)
    return resp
def ask_vet_after_chat(self, session):
    q1 ='Using the following veterinarian chat session as the input context, \n'
    q2 ='1. Write a short summary of the veterinarian chat session in a friendly natural conversation tone.\n'
    q3 ='2. Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}{q3}\n--------------------\nThe veterinarian chat session:\n\n{session}'
    resp = monty.geng_gpt4.query(question)
    return resp
@add_method(Pluto_Happy)
def ask_vet_email_after_chat(self, session):
    q1 ='Using the following veterinarian chat session as the input context, \n'
    q2 ='1. Write an summary email to the user from the veterinarian in a friendly natural conversation tone.\n'
    q3 ='2. Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}{q3}\n--------------------\nThe veterinarian chat session:\n\n{session}'
    resp = monty.geng_gpt4.query(question)
    return resp
@add_method(Pluto_Happy)
def ask_vet_web_user(self, profile):
    q1 ='Using the following user profile as the input context, \n'
    q2 ='1. Write fun web welcome messsage to the user and pet from the veterinarian in a friendly natural conversation tone.\n'
    q3 ='2. Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}{q3}\n--------------------\nThe user profile:\n\n{profile}'
    resp = monty.geng_gpt4.query(question)
    return resp
response = ask_vet_during_chat(monty, conversation)
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = ask_vet_after_chat(monty, conversation)
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = ask_vet_email_after_chat(monty, conversation)
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = ask_vet_web_user(monty, conversation)
print(textwrap.fill(str(response), width=120))
# Out:
# 1. "UTIs Suck for Your Cat, Too" :: https://thewildest.com/cat-health/cat-uti 2. "Spot lumps, limps, and lethargy early
# on" :: [article URL not provided]
# ----------------------------------------
# 1. Summary: The dog owner is concerned about their dog's frequent urination, pain, and unusual smell in the urine. The
# veterinarian suspects a urinary tract infection (UTI) and advises the owner to bring the dog to the clinic for a
# urinalysis. In the meantime, the owner is instructed to provide fresh water and prevent the dog from licking the
# affected area.  2. Recommended articles: 1. "Your Veterinarian's Top 8 Pet Peeves" :: https://thewildest.com/pet-
# health/veterinarians-pet-peeves 2. "UTIs Suck for Your Cat, Too | How to Treat Cat UTIs" :: https://thewildest.com/cat-
# health/cat-uti
# ----------------------------------------
# Subject: Your Dog's Urinary Tract Infection  Hi [Dog Owner's Name],  I hope this email finds you well. I wanted to
# ...

# %%
import textwrap
import pandas as pd
df = pd.read_csv('testing.csv')
conversation = df.loc[1, 'input']
@add_method(Pluto_Happy)
def ask_vet_after_chat(self, session):
    q1 ='Using the following veterinarian chat session as the input context, \n'
    q2 ='1. Write a short summary of the veterinarian chat session in a friendly natural conversation tone.\n'
    q3 ='2. Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}{q3}\n--------------------\nThe veterinarian chat session:\n\n{session}'
    resp = monty.geng_gpt4.query(question)
    return resp
response = ask_vet_after_chat(monty, conversation)
print(textwrap.fill(str(response), width=120))
# Out:
# 1. Summary of the veterinarian chat session: The dog owner contacted the veterinarian because their dog was experiencing
# frequent urination, pain, and unusual-smelling urine, which could be signs of a urinary tract infection (UTI). The
# veterinarian recommended bringing the dog to the clinic for a urinalysis to confirm the diagnosis. In the meantime, the
# owner was advised to ensure the dog had access to fresh water, prevent licking of the affected area, and avoid giving
# any over-the-counter medications without veterinary guidance. Dietary adjustments would be discussed based on the
# urinalysis results. The owner also asked about the possibility of UTIs being contagious to humans, and the veterinarian
# advised practicing good hygiene and consulting a doctor if any concerns arise.  2. Recommended articles: 1. "UTIs Suck
# for Your Cat, Too | How to Treat Cat UTIs" - Learn about the treatment options for cat UTIs and how to promote a healthy
# ...

# %%
import textwrap
import pandas as pd
df = pd.read_csv('testing.csv')
conversation = df.loc[1, 'input']
@add_method(Pluto_Happy)
def ask_vet_email_after_chat(self, session):
    q1 ='Using the following veterinarian chat session as the input context, \n'
    q2 ='1. Write an summary email to the user from the veterinarian in a friendly natural conversation tone.\n'
    q3 ='2. Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}{q3}\n--------------------\nThe veterinarian chat session:\n\n{session}'
    resp = monty.geng_gpt4.query(question)
    return resp
response = ask_vet_email_after_chat(monty, conversation)
print(textwrap.fill(str(response), width=120))
# Out:
# Subject: Summary and Recommendations for Your Dog's Urinary Tract Infection  Dear [Dog Owner],  I hope this email finds
# you well. I wanted to provide you with a summary of our recent chat session regarding your dog's urinary tract infection
# (UTI) and offer some recommendations moving forward.  Based on the symptoms you described, it is indeed possible that
# your dog has a UTI. To confirm the diagnosis, I recommend bringing him to the veterinary clinic for a urinalysis. This
# will help us determine the best course of treatment.  In the meantime, there are a few things you can do to ease your
# dog's discomfort. Make sure he has access to fresh water at all times to encourage urination and help flush out the
# urinary tract. It's also important to prevent him from licking the affected area, as this can lead to further
# irritation.  Regarding his diet, it's best to wait for the urinalysis results before making any dietary changes. Once we
# ...

# %%
import textwrap
import pandas as pd
df = pd.read_csv('testing.csv')
conversation = df.loc[2, 'input']
@add_method(Pluto_Happy)
def ask_vet_during_chat(self, session):
    q1 ='Using the following veterinarian chat session as the input context, \n'
    q2 ='Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}\n--------------------\nThe veterinarian chat session:\n\n{session}'
    resp = monty.geng_gpt4.query(question)
    return resp
def ask_vet_after_chat(self, session):
    q1 ='Using the following veterinarian chat session as the input context, \n'
    q2 ='1. Write a short summary of the veterinarian chat session in a friendly natural conversation tone.\n'
    q3 ='2. Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}{q3}\n--------------------\nThe veterinarian chat session:\n\n{session}'
    resp = monty.geng_gpt4.query(question)
    return resp
@add_method(Pluto_Happy)
def ask_vet_email_after_chat(self, session):
    q1 ='Using the following veterinarian chat session as the input context, \n'
    q2 ='1. Write an summary email to the user from the veterinarian in a friendly natural conversation tone.\n'
    q3 ='2. Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}{q3}\n--------------------\nThe veterinarian chat session:\n\n{session}'
    resp = monty.geng_gpt4.query(question)
    return resp
@add_method(Pluto_Happy)
def ask_vet_web_user(self, profile):
    q1 ='Using the following user profile as the input context, \n'
    q2 ='1. Write fun web welcome messsage to the user and pet from the veterinarian in a friendly natural conversation tone.\n'
    q3 ='2. Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}{q3}\n--------------------\nThe user profile:\n\n{profile}'
    resp = monty.geng_gpt4.query(question)
    return resp
response = ask_vet_during_chat(monty, conversation)
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = ask_vet_after_chat(monty, conversation)
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = ask_vet_email_after_chat(monty, conversation)
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = ask_vet_web_user(monty, conversation)
print(textwrap.fill(str(response), width=120))
# Out:
# 1. "UTIs Suck for Your Cat, Too" :: https://thewildest.com/cat-health/cat-uti 2. "Spot lumps, limps, and lethargy early
# on" :: [article URL not provided]
# ----------------------------------------
# 1. Summary of the veterinarian chat session in a friendly natural conversation tone: Cat Owner: Doctor, my cat has been
# urinating outside of the litter box and seems to be in discomfort. I suspect she may have a urinary tract infection. Can
# you help? Veterinarian: Hello! I'm sorry to hear that your cat is experiencing these symptoms. It's possible that she
# has a urinary tract infection (UTI). Let's schedule an appointment at the veterinary clinic for a thorough examination
# and urinalysis to confirm the diagnosis. Cat Owner: Thank you, Veterinarian. I'll make the appointment right away. In
# the meantime, is there anything I can do to relieve her discomfort? Veterinarian: While you wait for the appointment,
# ...

# %%
import textwrap
import pandas as pd
df = pd.read_csv('Vet_Chat_conv.csv')
conversation = df.loc[0, 'input']
@add_method(Pluto_Happy)
def ask_vet_during_chat(self, session):
    q1 ='Using the following veterinarian chat session as the input context, \n'
    q2 ='Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}\n--------------------\nThe veterinarian chat session:\n\n{session}'
    resp = monty.geng_gpt4.query(question)
    return resp
def ask_vet_after_chat(self, session):
    q1 ='Using the following veterinarian chat session as the input context, \n'
    q2 ='1. Write a short summary of the veterinarian chat session in a friendly natural conversation tone.\n'
    q3 ='2. Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}{q3}\n--------------------\nThe veterinarian chat session:\n\n{session}'
    resp = monty.geng_gpt4.query(question)
    return resp
@add_method(Pluto_Happy)
def ask_vet_email_after_chat(self, session):
    q1 ='Using the following veterinarian chat session as the input context, \n'
    q2 ='1. Write an summary email to the user from the veterinarian in a friendly natural conversation tone.\n'
    q3 ='2. Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}{q3}\n--------------------\nThe veterinarian chat session:\n\n{session}'
    resp = monty.geng_gpt4.query(question)
    return resp
@add_method(Pluto_Happy)
def ask_vet_web_user(self, profile):
    q1 ='Using the following user profile as the input context, \n'
    q2 ='1. Write fun web welcome messsage to the user and pet from the veterinarian in a friendly natural conversation tone.\n'
    q3 ='2. Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}{q3}\n--------------------\nThe user profile:\n\n{profile}'
    resp = monty.geng_gpt4.query(question)
    return resp
response = ask_vet_during_chat(monty, conversation)
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = ask_vet_after_chat(monty, conversation)
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = ask_vet_email_after_chat(monty, conversation)
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = ask_vet_web_user(monty, conversation)
print(textwrap.fill(str(response), width=120))
# Out:
# 1. "10 Tips to Achieve VetVisit Bliss For Your Dog" :: https://thewildest.com/dog-health/tips-vet-visit-bliss 2. "Your
# Veterinarian's Top 8 Pet Peeves" :: https://thewildest.com/pet-health/veterinarians-pet-peeves
# ----------------------------------------
# 1. Summary of the veterinarian chat session: In this friendly and natural conversation, a concerned dog owner reaches
# out to a veterinarian about their dog's unusual behavior. The veterinarian, Dr. Smith, introduces themselves and asks
# for more details about the dog's symptoms. The dog owner explains that their dog has been lethargic, lacking appetite,
# and licking their paws excessively. Dr. Johnson, a consulting physician, joins the conversation and suggests checking
# for signs of pain and running blood tests to rule out any underlying medical conditions. Dr. Smith assures the dog owner
# that they will perform a physical examination, discuss diet options, and consider any recent changes in the dog's
# ...

# %%
import textwrap
import pandas as pd
df = pd.read_csv('Vet_Chat_conv.csv')
conversation = df.loc[0, 'input']

@add_method(Pluto_Happy)
def ask_vet_during_chat(self, session):
    q1 ='Using the following veterinarian chat session as the input context, \n'
    q2 ='Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}\n--------------------\nThe veterinarian chat session:\n\n{session}'
    resp = monty.geng_gpt4.query(question)
    return resp
def ask_vet_after_chat(self, session):
    q1 ='Using the following veterinarian chat session as the input context, \n'
    q2 ='1. Write a short summary of the veterinarian chat session in a friendly natural conversation tone.\n'
    q3 ='2. Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}{q3}\n--------------------\nThe veterinarian chat session:\n\n{session}'
    resp = monty.geng_gpt4.query(question)
    return resp
@add_method(Pluto_Happy)
def ask_vet_email_after_chat(self, session):
    q1 ='Using the following veterinarian chat session as the input context, \n'
    q2 ='1. Write an summary email to the user from the veterinarian in a friendly natural conversation tone.\n'
    q3 ='2. Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}{q3}\n--------------------\nThe veterinarian chat session:\n\n{session}'
    resp = monty.geng_gpt4.query(question)
    return resp
@add_method(Pluto_Happy)
def ask_vet_web_user(self, profile):
    q1 ='Using the following user profile as the input context, \n'
    q2 ='1. Write fun web welcome messsage to the user and pet from the veterinarian in a friendly natural conversation tone.\n'
    q3 ='2. Recomend two best article in this format:\n1. kinship_artile_title :: the kinship_article_url.\n'
    question = f'{q1}{q2}{q3}\n--------------------\nThe user profile:\n\n{profile}'
    resp = monty.geng_gpt4.query(question)
    return resp
response = ask_vet_during_chat(monty, conversation)
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = ask_vet_after_chat(monty, conversation)
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = ask_vet_email_after_chat(monty, conversation)
print(textwrap.fill(str(response), width=120))
print("-" * 40)
response = ask_vet_web_user(monty, conversation)
print(textwrap.fill(str(response), width=120))
# Out:
# 1. "Your Dog Keeps Coughing: 7 Reasons You Should Be Concerned, According to Veterinarians" ::
# https://thewildest.com/dog-health/dog-coughing 2. "Your Veterinarian's Top 8 Pet Peeves" :: https://thewildest.com/pet-
# health/veterinarians-pet-peeves
# ----------------------------------------
# 1. In a friendly natural conversation tone: Dog Owner: Hi, Dr. Williams. My dog, Max, hasn't been himself lately. He's
# been lethargic, not eating much, and seems to be coughing. I'm really worried. Vet: I understand your concerns. Let me
# take a look at Max. Can you provide more details on when you first noticed these symptoms and if there have been any
# changes in his environment? Dog Owner: It started a few days ago. I haven't noticed any changes at home, but he's been
# less active and doesn't want to play fetch like he usually does. Vet: Thank you for sharing that. I'll conduct a
# ...

# %% [markdown]
# # API Testing

# %%
# prompt: rewrite the above function not to use mock but actual response from URL

import unittest
import json
import requests

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_valid_end_chat_status_success(self):
        """
        Test the endpoint with a valid "End_Chat" function option and check if the status is "success".
        """
        # Define the data to be sent to the API endpoint
        input_data = {
            "session": "my dog Monty is feeling sick.",
            "func_option": "End_Chat",
            "is_json": False
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

# if __name__ == '__main__':
#     unittest.main()
# I add ignore first error in the main function
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# E
# ...
# ERROR: test_valid_end_chat_status_success (__main__.TestChatAPI)
# Test the endpoint with a valid "End_Chat" function option and check if the status is "success".
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/tmp/ipykernel_10342/3015721333.py", line 31, in test_valid_end_chat_status_success
#     jdata = json.loads(response_data)
#   File "/home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "/home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/json/decoder.py", line 340, in decode
#     raise JSONDecodeError("Extra data", s, end)
# json.decoder.JSONDecodeError: Extra data: line 1 column 2 (char 1)
#
# ----------------------------------------------------------------------
# Ran 1 test in 5.238s
#
# FAILED (errors=1)

# %% [markdown]
# # API Unit test for End_Chat

# %%
#0 (Dog - Not feeling well) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_valid_end_chat_status_success(self):
        """
        Test the endpoint with a valid "End_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[0, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "End_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 12.251s
#
# OK
# {
#   "id": "ask_vet-1700643481",
#   "object": "chat.completion",
#   "created": 1700643481,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#1 (Cat - scratch disease) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_valid_end_chat_status_success(self):
        """
        Test the endpoint with a valid "End_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[1, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "End_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 4.644s
#
# OK
# {
#   "id": "ask_vet-1700674978",
#   "object": "chat.completion",
#   "created": 1700674978,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#2 Cat - (rabies) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_valid_end_chat_status_success(self):
        """
        Test the endpoint with a valid "End_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[2, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "End_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 5.422s
#
# OK
# {
#   "id": "ask_vet-1700643587",
#   "object": "chat.completion",
#   "created": 1700643587,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#3 Dog - (rabies) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_valid_end_chat_status_success(self):
        """
        Test the endpoint with a valid "End_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[3, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "End_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 9.790s
#
# OK
# {
#   "id": "ask_vet-1700675351",
#   "object": "chat.completion",
#   "created": 1700675351,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#4 (Cat - Ringworm) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_valid_end_chat_status_success(self):
        """
        Test the endpoint with a valid "End_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[4, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "End_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 6.565s
#
# OK
# {
#   "id": "ask_vet-1700675518",
#   "object": "chat.completion",
#   "created": 1700675518,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#5 Cat - prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_valid_end_chat_status_success(self):
        """
        Test the endpoint with a valid "End_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[5, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "End_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 5.786s
#
# OK
# {
#   "id": "ask_vet-1700675734",
#   "object": "chat.completion",
#   "created": 1700675734,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#6 "(Dog - Oral infections) "prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_valid_end_chat_status_success(self):
        """
        Test the endpoint with a valid "End_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[6, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "End_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 3.701s
#
# OK
# {
#   "id": "ask_vet-1700708271",
#   "object": "chat.completion",
#   "created": 1700708271,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#7 (Dog - Bacterial infections) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_valid_end_chat_status_success(self):
        """
        Test the endpoint with a valid "End_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[7, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "End_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 5.857s
#
# OK
# {
#   "id": "ask_vet-1700708381",
#   "object": "chat.completion",
#   "created": 1700708381,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#8 ("Cat - Oral infections) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_valid_end_chat_status_success(self):
        """
        Test the endpoint with a valid "End_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[8, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "End_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 5.001s
#
# OK
# {
#   "id": "ask_vet-1700708553",
#   "object": "chat.completion",
#   "created": 1700708553,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#9 (Cat Bacterial infections) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_valid_end_chat_status_success(self):
        """
        Test the endpoint with a valid "End_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[9, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "End_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 4.196s
#
# OK
# {
#   "id": "ask_vet-1700708730",
#   "object": "chat.completion",
#   "created": 1700708730,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %% [markdown]
# # API Unit test for Email

# %%
#0 (Dog - Not feeling well) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_email_status(self):
        """
        Test the endpoint with a valid "Email" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[0, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Email",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 9.413s
#
# OK
# {
#   "id": "ask_vet-1700674518",
#   "object": "chat.completion",
#   "created": 1700674518,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#1 (Cat - scratch disease) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_email_status(self):
        """
        Test the endpoint with a valid "Email" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[1, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Email",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 8.650s
#
# OK
# {
#   "id": "ask_vet-1700674962",
#   "object": "chat.completion",
#   "created": 1700674962,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#2 Cat - (rabies) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_email_status(self):
        """
        Test the endpoint with a valid "Email" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[2, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Email",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 9.195s
#
# OK
# {
#   "id": "ask_vet-1700675221",
#   "object": "chat.completion",
#   "created": 1700675221,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#3 Dog - (rabies) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_email_status(self):
        """
        Test the endpoint with a valid "Email" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[3, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Email",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 12.230s
#
# OK
# {
#   "id": "ask_vet-1700675650",
#   "object": "chat.completion",
#   "created": 1700675650,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#4 (Cat - Ringworm) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_email_status(self):
        """
        Test the endpoint with a valid "Email" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[4, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Email",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 9.515s
#
# OK
# {
#   "id": "ask_vet-1700675701",
#   "object": "chat.completion",
#   "created": 1700675701,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#5 Cat - prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_email_status(self):
        """
        Test the endpoint with a valid "Email" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[5, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Email",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 7.020s
#
# OK
# {
#   "id": "ask_vet-1700675787",
#   "object": "chat.completion",
#   "created": 1700675787,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#6 "(Dog - Oral infections) "prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_email_status(self):
        """
        Test the endpoint with a valid "Email" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[6, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Email",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 6.026s
#
# OK
# {
#   "id": "ask_vet-1700708294",
#   "object": "chat.completion",
#   "created": 1700708294,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#7 (Dog - Bacterial infections) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_email_status(self):
        """
        Test the endpoint with a valid "Email" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[7, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Email",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 10.172s
#
# OK
# {
#   "id": "ask_vet-1700708473",
#   "object": "chat.completion",
#   "created": 1700708473,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#8 ("Cat - Oral infections) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_email_status(self):
        """
        Test the endpoint with a valid "Email" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[8, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Email",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 9.066s
#
# OK
# {
#   "id": "ask_vet-1700708527",
#   "object": "chat.completion",
#   "created": 1700708527,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#9 (Cat Bacterial infections) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_email_status(self):
        """
        Test the endpoint with a valid "Email" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[9, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Email",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 10.813s
#
# OK
# {
#   "id": "ask_vet-1700708718",
#   "object": "chat.completion",
#   "created": 1700708718,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %% [markdown]
# # API Unit test for Mid_Chat

# %%
#0 (Dog - Not feeling well) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_mid_chat_status(self):
        """
        Test the endpoint with a valid "Mid_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[9, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Mid_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 2.375s
#
# OK
# {
#   "id": "ask_vet-1700708901",
#   "object": "chat.completion",
#   "created": 1700708901,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "1. UTIs Suck for Your Cat, Too | How to Treat Cat UTIs :: https://thewildest.com/cat-health/cat-uti\n2. How to Find the Right Vet For Your Cat :: https://thewildest.com/cat-health/how-to-find-a-cat-vet",
#         "metadata": [
#           {
#             "kinship_article_title": "How to Find the Right Vet For Your Cat",
#             "kinship_article_url": "https://thewildest.com/cat-health/how-to-find-a-cat-vet",
#             "kinship_author": "Charles Manning",
#             "kinship_entry_id": "430TY1UWx7G7XxvimajVyn",
#             "kinship_main_topic": "Health",
# ...

# %%
#1 (Cat - scratch disease) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_mid_chat_status(self):
        """
        Test the endpoint with a valid "Mid_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[1, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Mid_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 1.900s
#
# OK
# {
#   "id": "ask_vet-1700709026",
#   "object": "chat.completion",
#   "created": 1700709026,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "1. Does My Cat Have Zits? | How to Treat Cat Acne :: https://thewildest.com/cat-health/cat-acne\n2. Why is My Cat Limping? :: https://thewildest.com/cat-health/cat-limping",
#         "metadata": [
#           {
#             "kinship_article_title": "Why is My Cat Limping?",
#             "kinship_article_url": "https://thewildest.com/cat-health/cat-limping",
#             "kinship_author": "Charlotte Brackett",
#             "kinship_entry_id": "7B3xJwdYnReLSUhH6Z6oRR",
#             "kinship_main_topic": "Health",
#             "kinship_secondary_topics": "emergencies"
#           },
#           {
# ...

# %%
#2 Cat - (rabies) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_mid_chat_status(self):
        """
        Test the endpoint with a valid "Mid_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[2, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Mid_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 2.144s
#
# OK
# {
#   "id": "ask_vet-1700709053",
#   "object": "chat.completion",
#   "created": 1700709053,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "1. \"What Vaccines Does My Cat Need?\" :: https://thewildest.com/cat-health/what-vaccines-do-cats-need\n2. \"Everything you need to bring your kitty home for the holidays\" :: [No URL provided]",
#         "metadata": [
#           {
#             "kinship_article_title": "What Vaccines Does My Cat Need?",
#             "kinship_article_url": "https://thewildest.com/cat-health/what-vaccines-do-cats-need",
#             "kinship_author": "Bailey Freeman",
#             "kinship_entry_id": "79FiydcOnKToBTVKtR2BaH",
#             "kinship_main_topic": "Health",
#             "kinship_secondary_topics": "routine-care"
# ...

# %%
#3 Dog - (rabies) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_mid_chat_status(self):
        """
        Test the endpoint with a valid "Mid_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[3, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Mid_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 2.178s
#
# OK
# {
#   "id": "ask_vet-1700709082",
#   "object": "chat.completion",
#   "created": 1700709082,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "1. \"Rabies Vaccinations: Essential for Your Dog's Health\" :: https://www.example.com/rabies-vaccinations\n2. \"Understanding the Importance of Rabies Vaccinations for Dogs\" :: https://www.example.com/importance-of-rabies-vaccinations",
#         "metadata": [
#           {
#             "kinship_article_title": "All the Puppy Shots Your Dog Needs",
#             "kinship_article_url": "https://thewildest.com/dog-health/puppy-shots",
#             "kinship_author": "Oneal Bogan, DVM",
#             "kinship_entry_id": "4I6ZNg6vyqLA0LKPkTDBBw",
#             "kinship_main_topic": "Health",
# ...

# %%
#4 (Cat - Ringworm) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_mid_chat_status(self):
        """
        Test the endpoint with a valid "Mid_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[4, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Mid_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 2.027s
#
# OK
# {
#   "id": "ask_vet-1700709152",
#   "object": "chat.completion",
#   "created": 1700709152,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "1. Cat Allergies: Why Is My Cat Itchy? :: https://thewildest.com/cat-health/cat-allergies\n2. Does My Cat Have Zits? | How to Treat Cat Acne :: https://thewildest.com/cat-health/cat-acne",
#         "metadata": [
#           {
#             "kinship_article_title": "Does My Cat Have Zits? | How to Treat Cat Acne",
#             "kinship_article_url": "https://thewildest.com/cat-health/cat-acne",
#             "kinship_author": "Dr. Alycia Washington, DVM",
#             "kinship_entry_id": "2oJnSGc1B0ULgndmPiGOKX",
#             "kinship_main_topic": "Health",
# ...

# %%
#5 Cat - prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_mid_chat_status(self):
        """
        Test the endpoint with a valid "Mid_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[5, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Mid_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 1.970s
#
# OK
# {
#   "id": "ask_vet-1700709184",
#   "object": "chat.completion",
#   "created": 1700709184,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "1. \"Why Is My Cat Sneezing?\" :: https://thewildest.com/cat-health/cat-sneezing\n2. \"Why Is My Cat Coughing?\" :: https://thewildest.com/cat-health/cat-coughing",
#         "metadata": [
#           {
#             "kinship_article_title": "Why Is My Cat Coughing?",
#             "kinship_article_url": "https://thewildest.com/cat-health/cat-coughing",
#             "kinship_author": "Dr. Alycia Washington, DVM",
#             "kinship_entry_id": "5SLKpXAODyfgQy1xI6tq5o",
#             "kinship_main_topic": "Health",
#             "kinship_secondary_topics": "conditions-treatments| emergencies"
#           },
# ...

# %%
#6 "(Dog - Oral infections) "prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_mid_chat_status(self):
        """
        Test the endpoint with a valid "Mid_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[6, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Mid_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 1.956s
#
# OK
# {
#   "id": "ask_vet-1700709208",
#   "object": "chat.completion",
#   "created": 1700709208,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "1. Dental Disease in Dogs: Common Diseases, Prevention, and Treatment :: https://thewildest.com/dog-health/dental-disease-in-dogs\n2. The Importance of Dog Dental Care :: https://thewildest.com/dog-health/dog-dental-care",
#         "metadata": [
#           {
#             "kinship_article_title": "The Importance of Dog Dental Care",
#             "kinship_article_url": "https://thewildest.com/dog-health/dog-dental-care",
#             "kinship_author": "Marisa Meltzer",
#             "kinship_entry_id": "26kPRyUldn1MyAflD0H9wN",
#             "kinship_main_topic": "Health",
# ...

# %%
#7 (Dog - Bacterial infections) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_mid_chat_status(self):
        """
        Test the endpoint with a valid "Mid_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[7, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Mid_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 2.179s
#
# OK
# {
#   "id": "ask_vet-1700709236",
#   "object": "chat.completion",
#   "created": 1700709236,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "1. How to Relieve Your Dog's Itchy Skin :: https://thewildest.com/dog-health/vet-advice-relief-your-dogs-itchy-skin\n2. The Causes and Treatment of Bacterial Skin Infections in Dogs :: https://thewildest.com/dog-health/causes-treatment-bacterial-skin-infections-dogs",
#         "metadata": [
#           {
#             "kinship_article_title": "How to Relieve Your Dogs Itchy Skin",
#             "kinship_article_url": "https://thewildest.com/dog-health/vet-advice-relief-your-dogs-itchy-skin",
#             "kinship_author": "Robert J. Silver, DVM",
#             "kinship_entry_id": "bark-article-137",
# ...

# %%
#8 ("Cat - Oral infections) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_mid_chat_status(self):
        """
        Test the endpoint with a valid "Mid_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[8, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Mid_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 1.980s
#
# OK
# {
#   "id": "ask_vet-1700709268",
#   "object": "chat.completion",
#   "created": 1700709268,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "1. How to Brush Your Cat's Teeth | Best Cat Toothpaste and Dental Products :: https://thewildest.com/cat-health/cat-toothpaste\n2. Why Oral Care is Important For Cats :: https://thewildest.com/cat-health/cat-stress-oral-health",
#         "metadata": [
#           {
#             "kinship_article_title": "Why Oral Care is Important For Cats",
#             "kinship_article_url": "https://thewildest.com/cat-health/cat-stress-oral-health",
#             "kinship_author": "Jodi Helmer",
#             "kinship_entry_id": "xsG85HdbpkIkxU04m02d9",
#             "kinship_main_topic": "Health",
# ...

# %%
#9 (Cat Bacterial infections) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_mid_chat_status(self):
        """
        Test the endpoint with a valid "Mid_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[9, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Mid_Chat",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 1.833s
#
# OK
# {
#   "id": "ask_vet-1700709305",
#   "object": "chat.completion",
#   "created": 1700709305,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "1. UTIs Suck for Your Cat, Too | How to Treat Cat UTIs :: https://thewildest.com/cat-health/cat-uti\n2. How to Find the Right Vet For Your Cat :: https://thewildest.com/cat-health/how-to-find-a-cat-vet",
#         "metadata": [
#           {
#             "kinship_article_title": "How to Find the Right Vet For Your Cat",
#             "kinship_article_url": "https://thewildest.com/cat-health/how-to-find-a-cat-vet",
#             "kinship_author": "Charles Manning",
#             "kinship_entry_id": "430TY1UWx7G7XxvimajVyn",
#             "kinship_main_topic": "Health",
# ...

# %% [markdown]
# # API Unit test for Web_Weclome

# %%
import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_web_welcome_status(self):
        """
        Test the endpoint with a valid "End_Chat" function option and check if the status is "success".
        """
        conversations_df = pd.read_csv('/home/ec2-user/SageMaker/kin-ai-1/sandbox/akshatha-corner/Parent_intro.csv', usecols=['introduction'], nrows=12)

        # Loop over conversations in the dataframe
        for index, row in conversations_df.iterrows():
            session = row['introduction']  # Get the session from the dataframe

            input_data = {
                "session": session,
                "func_option": "Web_Welcome",
                "is_json": True
            }

            # Send data to the API endpoint
            response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)

            try:
                # Attempt JSON decoding
                response_data = response.json()
                jdata = json.loads(response_data)
                print(f"Response for index {index}:")
                print(f"Status Code: {response.status_code}")
                readable_text = json.dumps(jdata, indent=2)
                print(readable_text)
                print('\n ---------------------- \n')

                # Perform assertions
                self.assertEqual(response.status_code, 200)
                self.assertEqual(jdata['status'], 'success')
            except json.decoder.JSONDecodeError as e:
                print(f"Error decoding JSON for index {index}: {e}")
                print(f"Status Code: {response.status_code}")
                print(f"Response content: {response.text}")
                print('\n ---------------------- \n')
                # Handle the case where JSON decoding fails or the response content is empty or invalid
                # For the purpose of bypassing the test failure due to JSON decoding error, you might add a pass statement here

                pass

# Run the tests
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# Response for index 0:
# Status Code: 200
# {
#   "id": "ask_vet-1701101587",
#   "object": "chat.completion",
#   "created": 1701101587,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
# prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
#import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_web_welcome_status(self):
        """
        Test the endpoint with a valid "Mid_Chat" function option and check if the status is "success".
        """

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : "Jessica, a devoted cat owner, and her feline friend, Whiskers. Whiskers, a sleek and affectionate tabby, has always been the center of Jessica's world. However, recently, Jessica has noticed a change in Whiskers' behavior and appearance, indicating that her beloved cat is not feeling well.",
            "func_option": "Web_Welcome",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 4.453s
#
# OK
# {
#   "id": "ask_vet-1701097646",
#   "object": "chat.completion",
#   "created": 1701097646,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#1 (Cat - scratch disease) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_web_welcome_status(self):
        """
        Test the endpoint with a valid "Web_Welcome" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[1, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Web_Welcome",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 7.961s
#
# OK
# {
#   "id": "ask_vet-1700734317",
#   "object": "chat.completion",
#   "created": 1700734317,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#2 Cat - (rabies) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_web_welcome_status(self):
        """
        Test the endpoint with a valid "Web_Welcome" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[2, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Web_Welcome",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 15.683s
#
# OK
# {
#   "id": "ask_vet-1700726815",
#   "object": "chat.completion",
#   "created": 1700726815,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#3 Dog - (rabies) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_web_welcome_status(self):
        """
        Test the endpoint with a valid "Web_Welcome" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[3, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Web_Welcome",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 8.893s
#
# OK
# {
#   "id": "ask_vet-1700734342",
#   "object": "chat.completion",
#   "created": 1700734342,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#4 (Cat - Ringworm) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_web_welcome_status(self):
        """
        Test the endpoint with a valid "Web_Welcome" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[4, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Web_Welcome",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 12.420s
#
# OK
# {
#   "id": "ask_vet-1700734365",
#   "object": "chat.completion",
#   "created": 1700734365,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#5 Cat - prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_web_welcome_status(self):
        """
        Test the endpoint with a valid "Web_Welcome" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[5, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Web_Welcome",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 7.539s
#
# OK
# {
#   "id": "ask_vet-1700734386",
#   "object": "chat.completion",
#   "created": 1700734386,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
#6 "(Dog - Oral infections) "prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_web_welcome_status(self):
        """
        Test the endpoint with a valid "Web_Welcome" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[6, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Web_Welcome",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)

# %%
#7 (Dog - Bacterial infections) prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_web_welcome_status(self):
        """
        Test the endpoint with a valid "Web_Welcome" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[7, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Web_Welcome",
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        #print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

        readable_text = json.dumps(jdata, indent=2)
        print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 7.740s
#
# OK
# {
#   "id": "ask_vet-1700734401",
#   "object": "chat.completion",
#   "created": 1700734401,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %% [markdown]
# # Invalid Functions

# %%
import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_invalid_function_status(self):
        """
        Test the endpoint with a valid "End_Chat" function option and check if the status is "success".
        """
        conversations_df = pd.read_csv('/home/ec2-user/SageMaker/kin-ai-1/sandbox/akshatha-corner/fail_functions.csv', usecols=['function'], nrows=23)

        # Loop over conversations in the dataframe
        for index, row in conversations_df.iterrows():
            session = row['function']  # Get the session from the dataframe

            input_data = {
                "session": "Emily, a devoted cat owner, is troubled by her usually affectionate Siamese cat, Luna, who has been hiding under furniture and avoiding interaction",
                "func_option": session,
                "is_json": True
            }

            # Send data to the API endpoint
            response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)

            try:
                # Attempt JSON decoding
                response_data = response.json()
                jdata = json.loads(response_data)
                print(f"Response for index {index}:")
                print(f"Status Code: {response.status_code}")
                readable_text = json.dumps(jdata, indent=2)
                print(readable_text)
                print('\n ---------------------- \n')

                # Perform assertions
                self.assertEqual(response.status_code, 200)
                self.assertEqual(jdata['status'], 'error')
            except json.decoder.JSONDecodeError as e:
                print(f"Error decoding JSON for index {index}: {e}")
                print(f"Status Code: {response.status_code}")
                print(f"Response content: {response.text}")
                print('\n ---------------------- \n')
                # Handle the case where JSON decoding fails or the response content is empty or invalid
                # For the purpose of bypassing the test failure due to JSON decoding error, you might add a pass statement here

                pass

# Run the tests
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# Response for index 0:
# Status Code: 200
# {
#   "id": "ask_vet-1701096822",
#   "object": "chat.completion",
#   "created": 1701096822,
#   "model": "gpt-4-0613",
#   "status": "error",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Error: Invalid function: end_chat\n---------------\nOption: end_chat\nIsjson: True\nChat: Emily, a devoted cat owner, is troubled by her usually affectionate Siamese cat, Luna, who has been hiding under furniture and avoiding interaction",
#         "metadata": [],
#         "score": []
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 1,
#     "completion_tokens": 1,
#     "total_tokens": 2
#   },
#   "meta": {
#     "est_cost": 0.01,
#     "est_cpu_sec": 0.01,
#     "vet_option": "end_chat",
#     "error_mesg": "Error: Invalid function: end_chat"
#   }
# }
#
#  ----------------------
#
# Response for index 1:
# Status Code: 200
# {
# ...

# %%
# prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests

class TestChatAPI(unittest.TestCase):


    def test_end_chat_status_failure(self):
        """
        Test the endpoint with a "End_Chat" function option and simulate a failure response by sending incorrect data.
        """
        # Define incorrect data to be sent to the API endpoint to simulate a failure
        input_data = {
            "session": "my dog Monty is feeling sick.",
            "func_option": "End_Chat",  # This should cause a failure
            "is_json": Trues
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        print(f"hello: {response.json()}")

        # Check if the response status code is not 200 (OK)
        print(f"hello 2: {response.status_code}")
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is not 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'error')

# if __name__ == '__main__':
#     unittest.main()
# I add ignore first error in the main function
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# E
# ...
# ERROR: test_end_chat_status_failure (__main__.TestChatAPI)
# Test the endpoint with a "End_Chat" function option and simulate a failure response by sending incorrect data.
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/tmp/ipykernel_25239/282788829.py", line 18, in test_end_chat_status_failure
#     "is_json": Trues
# NameError: name 'Trues' is not defined
#
# ----------------------------------------------------------------------
# Ran 1 test in 0.001s
#
# FAILED (errors=1)

# %%
# prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests

class TestChatAPI(unittest.TestCase):


    def test_end_chat_status_failure(self):
        """
        Test the endpoint with a "End_Chat" function option and simulate a failure response by sending incorrect data.
        """
        # Define incorrect data to be sent to the API endpoint to simulate a failure
        input_data = {
            "session": "my dog Monty is feeling sick.",
            "func_option": "Em",  # This should cause a failure
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        print(f"hello: {response.json()}")

        # Check if the response status code is not 200 (OK)
        print(f"hello 2: {response.status_code}")
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is not 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'error')

# if __name__ == '__main__':
#     unittest.main()
# I add ignore first error in the main function
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.034s
#
# OK
# hello: {"id": "ask_vet-1701101900", "object": "chat.completion", "created": 1701101900, "model": "gpt-4-0613", "status": "error", "choices": [{"index": 0, "message": {"role": "assistant", "content": "Error: Invalid function: Em\n---------------\nOption: Em\nIsjson: True\nChat: my dog Monty is feeling sick.", "metadata": [], "score": []}, "finish_reason": "stop"}], "usage": {"prompt_tokens": 1, "completion_tokens": 1, "total_tokens": 2}, "meta": {"est_cost": 0.01, "est_cpu_sec": 0.01, "vet_option": "Em", "error_mesg": "Error: Invalid function: Em"}}
# hello 2: 200

# %%
# prompt: rewrite the above function not to use mock but actual response from URL.

import unittest
import json
import requests

class TestChatAPI(unittest.TestCase):


    def test_end_chat_status_failure(self):
        """
        Test the endpoint with a "End_Chat" function option and simulate a failure response by sending incorrect data.
        """
        # Define incorrect data to be sent to the API endpoint to simulate a failure
        input_data = {
            "session": "my dog Monty is feeling sick.",
            "func_option": "Web Welcome",  # This should cause a failure
            "is_json": True
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        print(f"hello: {response.json()}")

        # Check if the response status code is not 200 (OK)
        print(f"hello 2: {response.status_code}")
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is not 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'error')

# if __name__ == '__main__':
#     unittest.main()
# I add ignore first error in the main function
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 0.037s
#
# OK
# hello: {"id": "ask_vet-1701101969", "object": "chat.completion", "created": 1701101969, "model": "gpt-4-0613", "status": "error", "choices": [{"index": 0, "message": {"role": "assistant", "content": "Error: Invalid function: Web Welcome\n---------------\nOption: Web Welcome\nIsjson: True\nChat: my dog Monty is feeling sick.", "metadata": [], "score": []}, "finish_reason": "stop"}], "usage": {"prompt_tokens": 1, "completion_tokens": 1, "total_tokens": 2}, "meta": {"est_cost": 0.01, "est_cpu_sec": 0.01, "vet_option": "Web Welcome", "error_mesg": "Error: Invalid function: Web Welcome"}}
# hello 2: 200

# %%
import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_invalid_function_status(self):
        """
        Test the endpoint with a valid "Mid_Chat" function option and check if the status is "success".
        """
        conversations_df = pd.read_csv('/home/ec2-user/SageMaker/kin-ai-1/sandbox/akshatha-corner/Vet_Chat_conv.csv', usecols=['input'], nrows=10)

        # Loop over conversations in the dataframe
        for index, row in conversations_df.iterrows():
            session = row['input']  # Get the session from the dataframe

            input_data = {
                "session": session,
                "func_option": "Mid_Chat",
                "is_json": True
            }

            # Send data to the API endpoint
            response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)

            try:
                # Attempt JSON decoding
                response_data = response.json()
                jdata = json.loads(response_data)
                print(f"Response for index {index}:")
                print(f"Status Code: {response.status_code}")
                readable_text = json.dumps(jdata, indent=2)
                print(readable_text)
                print('\n ---------------------- \n')

                # Perform assertions
                self.assertEqual(response.status_code, 200)
                self.assertEqual(jdata['status'], 'error')
            except json.decoder.JSONDecodeError as e:
                print(f"Error decoding JSON for index {index}: {e}")
                print(f"Status Code: {response.status_code}")
                print(f"Response content: {response.text}")
                print('\n ---------------------- \n')
                # Handle the case where JSON decoding fails or the response content is empty or invalid
                # For the purpose of bypassing the test failure due to JSON decoding error, you might add a pass statement here

                pass

# Run the tests
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# F
# ...
# FAIL: test_invalid_function_status (__main__.TestChatAPI)
# Test the endpoint with a valid "Mid_Chat" function option and check if the status is "success".
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/tmp/ipykernel_25239/390171301.py", line 43, in test_invalid_function_status
#     self.assertEqual(jdata['status'], 'error')
# AssertionError: 'success' != 'error'
# - success
# + error
#
#
# ----------------------------------------------------------------------
# Ran 1 test in 2.482s
#
# FAILED (failures=1)
# Response for index 0:
# Status Code: 200
# {
#   "id": "ask_vet-1701102332",
#   "object": "chat.completion",
#   "created": 1701102332,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_invalid_function_status(self):
        """
        Test the endpoint with a valid "Email" function option and check if the status is "success".
        """
        conversations_df = pd.read_csv('/home/ec2-user/SageMaker/kin-ai-1/sandbox/akshatha-corner/Vet_Chat_conv.csv', usecols=['input'], nrows=10)

        # Loop over conversations in the dataframe
        for index, row in conversations_df.iterrows():
            session = row['input']  # Get the session from the dataframe

            input_data = {
                "session": session,
                "func_option": "Email",
                "is_json": True
            }

            # Send data to the API endpoint
            response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)

            try:
                # Attempt JSON decoding
                response_data = response.json()
                jdata = json.loads(response_data)
                print(f"Response for index {index}:")
                print(f"Status Code: {response.status_code}")
                readable_text = json.dumps(jdata, indent=2)
                print(readable_text)
                print('\n ---------------------- \n')

                # Perform assertions
                self.assertEqual(response.status_code, 200)
                self.assertEqual(jdata['status'], 'error')
            except json.decoder.JSONDecodeError as e:
                print(f"Error decoding JSON for index {index}: {e}")
                print(f"Status Code: {response.status_code}")
                print(f"Response content: {response.text}")
                print('\n ---------------------- \n')
                # Handle the case where JSON decoding fails or the response content is empty or invalid
                # For the purpose of bypassing the test failure due to JSON decoding error, you might add a pass statement here

                pass

# Run the tests
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# F
# ...
# FAIL: test_invalid_function_status (__main__.TestChatAPI)
# Test the endpoint with a valid "Email" function option and check if the status is "success".
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/tmp/ipykernel_25239/3750380328.py", line 43, in test_invalid_function_status
#     self.assertEqual(jdata['status'], 'error')
# AssertionError: 'success' != 'error'
# - success
# + error
#
#
# ----------------------------------------------------------------------
# Ran 1 test in 15.849s
#
# FAILED (failures=1)
# Response for index 0:
# Status Code: 200
# {
#   "id": "ask_vet-1701102599",
#   "object": "chat.completion",
#   "created": 1701102599,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_invalid_function_status(self):
        """
        Test the endpoint with a valid "Web_Welcome" function option and check if the status is "success".
        """
        conversations_df = pd.read_csv('/home/ec2-user/SageMaker/kin-ai-1/sandbox/akshatha-corner/Vet_Chat_conv.csv', usecols=['input'], nrows=10)

        # Loop over conversations in the dataframe
        for index, row in conversations_df.iterrows():
            session = row['input']  # Get the session from the dataframe

            input_data = {
                "session": session,
                "func_option": "Web_Welcome",
                "is_json": True
            }

            # Send data to the API endpoint
            response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)

            try:
                # Attempt JSON decoding
                response_data = response.json()
                jdata = json.loads(response_data)
                print(f"Response for index {index}:")
                print(f"Status Code: {response.status_code}")
                readable_text = json.dumps(jdata, indent=2)
                print(readable_text)
                print('\n ---------------------- \n')

                # Perform assertions
                self.assertEqual(response.status_code, 200)
                self.assertEqual(jdata['status'], 'error')
            except json.decoder.JSONDecodeError as e:
                print(f"Error decoding JSON for index {index}: {e}")
                print(f"Status Code: {response.status_code}")
                print(f"Response content: {response.text}")
                print('\n ---------------------- \n')
                # Handle the case where JSON decoding fails or the response content is empty or invalid
                # For the purpose of bypassing the test failure due to JSON decoding error, you might add a pass statement here

                pass

# Run the tests
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# F
# ...
# FAIL: test_invalid_function_status (__main__.TestChatAPI)
# Test the endpoint with a valid "Web_Welcome" function option and check if the status is "success".
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/tmp/ipykernel_25239/4154932642.py", line 43, in test_invalid_function_status
#     self.assertEqual(jdata['status'], 'error')
# AssertionError: 'success' != 'error'
# - success
# + error
#
#
# ----------------------------------------------------------------------
# Ran 1 test in 9.219s
#
# FAILED (failures=1)
# Response for index 0:
# Status Code: 200
# {
#   "id": "ask_vet-1701102611",
#   "object": "chat.completion",
#   "created": 1701102611,
#   "model": "gpt-4-0613",
#   "status": "success",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
# ...

# %%
import unittest
import json
import requests

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_valid_end_chat_status_success(self):
        """
        Test the endpoint with a valid "End_Chat" function option and check if the status is "success".
        """
        # Define the data to be sent to the API endpoint
        input_data = {
            "session": "my dog Monty is feeling okay after vaccine.",
            "func_option": "End_Chat",
            "is_json": False
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        print(f"hello 1: {response.json()}")

        # Check if the response status code is 200 (OK)
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'success')

    def test_end_chat_status_failure(self):
        """
        Test the endpoint with a "End_Chat" function option and simulate a failure response by sending incorrect data.
        """
        # Define incorrect data to be sent to the API endpoint to simulate a failure
        input_data = {
            "session": "my dog Monty is feeling sick.",
            "func_option": "Invalid_Option",  # This should cause a failure
            "is_json": False
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        print(f"hello: {response.json()}")

        # Check if the response status code is not 200 (OK)
        print(f"hello 2: {response.status_code}")
        self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is not 'success'
        response_data = response.json()
        jdata = json.loads(response_data)
        self.assertEqual(jdata['status'], 'error')

# if __name__ == '__main__':
#     unittest.main()
# I add ignore first error in the main function
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# E
# hello: Error: Invalid function: Invalid_Option
# ---------------
# Option: Invalid_Option
# Isjson: False
# Chat: my dog Monty is feeling sick.
# hello 2: 200
# E
# ...
# ERROR: test_end_chat_status_failure (__main__.TestChatAPI)
# Test the endpoint with a "End_Chat" function option and simulate a failure response by sending incorrect data.
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "/tmp/ipykernel_25239/3033558310.py", line 54, in test_end_chat_status_failure
#     jdata = json.loads(response_data)
#   File "/home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/json/__init__.py", line 346, in loads
#     return _default_decoder.decode(s)
#   File "/home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/json/decoder.py", line 337, in decode
#     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#   File "/home/ec2-user/anaconda3/envs/pytorch_p310/lib/python3.10/json/decoder.py", line 355, in raw_decode
# ...

# %% [markdown]
# # Testing 5 Recommended articles

# %%
import unittest
import json
import requests
import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_valid_end_chat_status_success(self):
        """
        Test the endpoint with a valid "End_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[0, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "End_Chat",
            "is_json": False
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        print(response.json())
        print(textwrap.fill(str(response), width=120))

        # Check if the response status code is 200 (OK)
        #self.assertEqual(response.status_code, 200)

        # Check if the 'status' field in the response is 'success'
        #response_data = response.json()
        #jdata = json.loads(response_data)
        #self.assertEqual(jdata['status'], 'success')

        #readable_text = json.dumps(jdata, indent=2)
        #print(readable_text)

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# ----------------------------------------------------------------------
# Ran 1 test in 9.323s
#
# OK
# 1. Summary of the veterinarian chat session:
# In this chat session, a dog owner named Max expresses concern about his dog's recent lethargy, decreased appetite, and coughing. The veterinarian, Dr. Williams, assures the owner that they understand his worries and will examine Max thoroughly. Dr. Turner, a consulting physician, suggests checking for respiratory issues and recommends a chest X-ray. The vet advises the owner to provide a warm and quiet space for Max to rest and to monitor his water intake. They promise to keep the owner updated on the results and discuss the next steps based on their findings.
#
# 2. Recommended kinship articles:
# 1. "Your Veterinarian's Top 8 Pet Peeves" :: https://thewildest.com/pet-health/veterinarians-pet-peeves
# 2. "10 Tips to Achieve VetVisit Bliss For Your Dog" :: https://thewildest.com/dog-health/tips-vet-visit-bliss
# ...

# %%
# calling all 4 Methods - End_Chat, Mid_Chat, Email, Web_Welcome

import unittest
import json
import requests
import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_valid_end_chat_status_success(self):
        """
        Test the endpoint with a valid "End_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[0, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "End_Chat",
            "is_json": False
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        print(response.json())
        print(textwrap.fill(str(response), width=120))

    def test_valid_mid_chat_status_success(self):
        """
        Test the endpoint with a valid "Mid_Chat" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[0, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Mid_Chat",
            "is_json": False
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        print(response.json())
        print(textwrap.fill(str(response), width=120))

    def test_valid_email_status_success(self):
        """
        Test the endpoint with a valid "Email" function option and check if the status is "success".
        """

        df = pd.read_csv('Vet_Chat_conv.csv')
        convo = df.loc[0, 'input']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Email",
            "is_json": False
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        print(response.json())
        print(textwrap.fill(str(response), width=120))

    def test_valid_web_welcome_status_success(self):
        """
        Test the endpoint with a valid "Web_Welcome" function option and check if the status is "success".
        """

        df = pd.read_csv('Parent_intro.csv')
        convo = df.loc[0, 'introduction']

        # Define the data to be sent to the API endpoint
        input_data = {
            "session" : convo,
            "func_option": "Web_Welcome",
            "is_json": False
        }

        # Send data to the API endpoint
        response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
        #print(f"hello 1: {response.json()}")
        print(response.json())
        print(textwrap.fill(str(response), width=120))

unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# Subject: Update on Max's Health and Recommendations for Further Reading
#
# Hi [Dog Owner's Name],
#
# I hope this email finds you well. I wanted to provide you with an update on Max's health and also recommend some informative articles that might be helpful for you as a pet owner.
#
# During our examination, we observed that Max has been experiencing lethargy, decreased appetite, and a persistent cough. To further investigate these symptoms, we conducted a thorough examination and consulted with Dr. Turner, our experienced physician.
#
# Based on our initial assessment, we suspect that Max may be experiencing respiratory issues. To gain a better understanding of his condition, we have decided to perform a chest X-ray to check for any abnormalities in his lungs or airways. Additionally, we will be monitoring his temperature and overall well-being closely.
#
# ...

# %% [markdown]
# # 5 Recommended articles - End_Chat

# %%
import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_end_chat_status(self):
        """
        Test the endpoint with a valid "End_Chat" function option and check if the status is "success".
        """
        conversations_df = pd.read_csv('/home/ec2-user/SageMaker/kin-ai-1/sandbox/akshatha-corner/Vet_Chat_conv.csv', usecols=['input'], nrows=12)

        # Loop over conversations in the dataframe
        for index, row in conversations_df.iterrows():
            session = row['input']  # Get the session from the dataframe

            input_data = {
                "session": session,
                "func_option": "End_Chat",
                "is_json": False
            }

            # Send data to the API endpoint
            response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
            print(response.json())
            print(textwrap.fill(str(response), width=120))
            print('\n ---------------------- \n')

# Run the tests
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# lethargic, not eating much, coughing, less active, fever, chest X-ray, abnormalities in lungs or airways, signs of difficulty breathing, treatment plan
# <Response [200]>
#
#  ----------------------
#
# swollen lymph nodes, lethargic, scratch, minor, serious, Cat Scratch Disease, blood tests, fever, infection, antibiotics, self-limiting condition, complications, treatment plan, additional care
# <Response [200]>
#
#  ----------------------
#
# rabies, vaccinations, preventable disease, health and safety, exposed to wildlife, serious and often fatal disease, transmitted to humans, zoonotic, vaccination schedule, annual vaccinations, longer duration, current on shots, vaccine, appointment
# <Response [200]>
#
#  ----------------------
#
# ...

# %% [markdown]
# # 5 Recommended articles - Mid_Chat

# %%
import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_mid_chat_status(self):
        """
        Test the endpoint with a valid "Mid_Chat" function option and check if the status is "success".
        """
        conversations_df = pd.read_csv('/home/ec2-user/SageMaker/kin-ai-1/sandbox/akshatha-corner/Vet_Chat_conv.csv', usecols=['input'], nrows=12)

        # Loop over conversations in the dataframe
        for index, row in conversations_df.iterrows():
            session = row['input']  # Get the session from the dataframe

            input_data = {
                "session": session,
                "func_option": "Mid_Chat",
                "is_json": False
            }

            # Send data to the API endpoint
            response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
            print(response.json())
            print(textwrap.fill(str(response), width=120))
            print('\n ---------------------- \n')

# Run the tests
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# 1. How to Get A Head Start on Your Pet's Health | Preventive Pet Care is Key :: https://thewildest.com/pet-health/preventive-care
# 2. Your Veterinarian's Top 8 Pet Peeves :: https://thewildest.com/pet-health/veterinarians-pet-peeves
# 3. Leap Venture Studio: Designing Flexitarian Pet Diets and State-of-the-Art Health Tools :: https://thewildest.com/pet-health/leap-venture-studio
# 4. How to Recognize Dental Issues in Your Pet and Why Early Detection is Important :: https://thewildest.com/pet-health/dental-issues-in-pets
# 5. The Importance of Spaying or Neutering Your Pet for Their Health and the Overpopulation Problem :: https://thewildest.com/pet-health/spaying-neutering
# <Response [200]>
#
#  ----------------------
#
# 1. How to Get A Head Start on Your Pet's Health | Preventive Pet Care is Key :: https://thewildest.com/pet-health/preventive-care
# 2. How to Find the Right Vet For Your Cat :: https://thewildest.com/cat-health/how-to-find-a-cat-vet
# ...

# %% [markdown]
# # 5 Recommended articles - Email

# %%
import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_email_status(self):
        """
        Test the endpoint with a valid "Email" function option and check if the status is "success".
        """
        conversations_df = pd.read_csv('/home/ec2-user/SageMaker/kin-ai-1/sandbox/akshatha-corner/Vet_Chat_conv.csv', usecols=['input'], nrows=12)

        # Loop over conversations in the dataframe
        for index, row in conversations_df.iterrows():
            session = row['input']  # Get the session from the dataframe

            input_data = {
                "session": session,
                "func_option": "Email",
                "is_json": False
            }

            # Send data to the API endpoint
            response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
            print(response.json())
            print(textwrap.fill(str(response), width=120))
            print('\n ---------------------- \n')

# Run the tests
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# Subject: Update on Max's Health and Recommendations for Further Reading
#
# Hi [Dog Owner's Name],
#
# I hope this email finds you well. I wanted to provide you with an update on Max's health and also recommend some informative articles that might be helpful for you as a pet owner.
#
# During our examination, we noticed that Max has been experiencing lethargy, decreased appetite, and a persistent cough. To further investigate these symptoms, we conducted a thorough examination and consulted with Dr. Turner, our respiratory specialist. Based on our initial assessment, we have decided to perform a chest X-ray to check for any abnormalities in Max's lungs or airways.
#
# In the meantime, there are a few things you can do at home to make Max more comfortable. Providing him with a warm and quiet space to rest is important. Keep an eye on his water intake, and if his coughing persists or if he shows any signs of difficulty breathing, please don't hesitate to reach out to us immediately.
#
# ...

# %% [markdown]
# # 5 Recommended articles - Web_Welcome

# %%
import unittest
import json
import requests
#import textwrap
import pandas as pd

class TestChatAPI(unittest.TestCase):
    """
    This class contains unit tests for the Chat API endpoint that make real HTTP requests.
    """

    def test_web_welcome_status(self):
        """
        Test the endpoint with a valid "Wel_Welcome" function option and check if the status is "success".
        """
        conversations_df = pd.read_csv('/home/ec2-user/SageMaker/kin-ai-1/sandbox/akshatha-corner/Parent_intro.csv', usecols=['introduction'], nrows=12)

        # Loop over conversations in the dataframe
        for index, row in conversations_df.iterrows():
            session = row['introduction']  # Get the session from the dataframe

            input_data = {
                "session": session,
                "func_option": "Web_Welcome",
                "is_json": False
            }

            # Send data to the API endpoint
            response = requests.post('https://kinship-ai.staging.kinship-ai.com/ask_vet/', json=input_data)
            print(response.json())
            print(textwrap.fill(str(response), width=120))
            print('\n ---------------------- \n')

# Run the tests
unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# Hey there, John and Rocky! Welcome to our virtual veterinary clinic. We're so glad you found us. We understand how important Rocky is to you, and we're here to help.
#
# Rocky, we know you're a spirited and loyal Golden Retriever who brings so much joy and excitement to John's life. We want to make sure you stay healthy and happy, so let's tackle that dental problem together!
#
# Now, let's dive into some helpful articles that might provide some insights and tips for you:
#
# 1. "The Importance of Dental Care for Dogs" :: https://thewildest.com/pet-health/dental-care-dogs
# 2. "How to Keep Your Dog's Teeth Clean and Healthy" :: https://thewildest.com/dog-health/teeth-clean-healthy
# 3. "Signs of Dental Problems in Dogs: What to Look Out For" :: https://thewildest.com/pet-health/signs-dental-problems-dogs
# 4. "Tips for Brushing Your Dog's Teeth at Home" :: https://thewildest.com/dog-health/brushing-teeth-home
# ...

# %% [markdown]
# # CONCLUSION
#
# 1. By default we can see URL related to Dog If user won't mention Dog or Cat
# 2. "How to Find a Cat Vet" artical (https://thewildest.com/cat-health/how-to-find-a-cat-vet) is recommended for most of the chats.
# 3. For Vaccinations and Bacterial infections related chat, I am seeing only one artical but its shown 2 times
# 4. In Email function output: [kinship_article_url] is shown instead of artical URL
# 5. In an Email function instance, output doesnt show article link or placeholder.
# 6. In Web_Welcome function, [kinship_article_title :: kinship_article_url]\n\n is shown in output

# %% [markdown]
# # CONCLUSION 11/29 - V3
#
# 1. In End_Chat function, [URL] [URL is not provided] is shown in LLM response
# 2. In Email function, [Link to the article], [kinship_article_url] is shown in LLM response
# 3. No articles are shown in some of the Email response
# 4. In Web_Welcome function, (article_url), [kinship_article_url] and [Link to the article] is shown in LLM response
# 5. Session input is tooking around 10 to 15 seconds to generate the output.
